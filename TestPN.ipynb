# %%
import numpy as np
import matplotlib.pyplot as plt
from PYPostNewtonian.Code import PostNewtonian
import scri

W1,chiAE,chiBE=PostNewtonian.PNWaveform(1.6, 0.006, np.array([-2.7e-01, -6.4e-02,  3.7e-01]), np.array([ 3.9e-01 , 1.1e-01 ,-3.6e-01]),return_chi=True)
W1.to_inertial_frame()
fig, (ax1) = plt.subplots(1,1)
ax1.plot(W1.t,np.real(W1.data[:,3])-np.imag(W1.data[:,3]), linewidth=2.0, label='(2,1) mode')
ax1.legend()
# Out:
# /home/dzsun/Hybrid/HybridizationWaveforms/PYPostNewtonian/Code/PNEvolution.py:1028: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, A))
#   Vars.chi1_n = np.array([dot(Vars.chiVec1[1:],Vars.nHat[1:])])
# /home/dzsun/Hybrid/HybridizationWaveforms/PYPostNewtonian/Code/PNEvolution.py:1028: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, A))
#   Vars.chi1_n = np.array([dot(Vars.chiVec1[1:],Vars.nHat[1:])])
