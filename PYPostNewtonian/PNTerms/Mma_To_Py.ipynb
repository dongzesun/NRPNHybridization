# %%
s=['Subscript[\[CapitalSigma], l]','Subscript[S, l]','\[Delta]','\[Nu]','Sqrt','[',']','^','Pi','Plus',',',
   'psim(',' ','\n',';',')=']
s_PsiM=['Sigma_ell','S_ell','delta','nu','sqrt','(',')','**','pi','+','_',
      'WaveformModes_Spin_Symm.AddDerivedVariable(\'hHat_spin_Symm_','','','),\n    datatype=\'std::complex<double>\')\n','\',\n    (']
s_h=['Sigma_ell','S_ell','delta','nu','sqrt','(',')','**','pi','+','_',
      'WaveformModes_Spin_Symm.AddDerivedVariable(\'hHat_spin_Symm_','','','),\n    datatype=\'std::complex<double>\')\n','\',\n    -(sqrt(5/6)/4)*(']
term="""psim[2, 0, 
   5] = (179869*Sqrt[5]*Subscript[S, l])/(74088*M^2) + (289127*
      Sqrt[5]*\[Delta]*Subscript[\[CapitalSigma], l])/(790272*
      M^2) + \[Nu]*((319*Sqrt[5]*Subscript[S, l])/(882*M^2) + (1775*
         Sqrt[5]*\[Delta]*Subscript[\[CapitalSigma], l])/(9408*M^2)); 
psim[2, 0, 
   6] = \[Delta]*((23*Sqrt[5]*Pi*Subscript[\[CapitalSigma], l])/(1344*
         M^2) + (173191*Sqrt[5]*Subscript[S, l]*
         Subscript[\[CapitalSigma], l])/(56448*M^4)) + (Sqrt[
       5]*(63808*Subscript[S, l]^2 + 
        99197*Subscript[\[CapitalSigma], l]^2))/(75264*
      M^4) + (\[Nu]^2*(31*Sqrt[5]*
        Subscript[\[CapitalSigma], l]^2))/(42*
      M^4) + \[Nu]*(-((31*Sqrt[5]*\[Delta]*Subscript[S, l]*
           Subscript[\[CapitalSigma], l])/(42*M^4)) - (Sqrt[
          5]*(20832*Subscript[S, l]^2 + 
           142529*Subscript[\[CapitalSigma], l]^2))/(28224*M^4)); 
psim[2, 0, 
   7] = (9724899179*Sqrt[5]*Subscript[S, l])/(1056198528*
      M^2) + \[Nu]^2*(-((34739*Sqrt[5]*Subscript[S, l])/(49896*
           M^2)) - (66403*Sqrt[5]*\[Delta]*
         Subscript[\[CapitalSigma], l])/(177408*M^2)) + (Sqrt[
       5]*(36992*Subscript[S, l]^3 + 
        22539*Subscript[S, l]*Subscript[\[CapitalSigma], l]^2))/(1512*
      M^6) + (Pi*(-(Sqrt[
           5]*(3072*Subscript[S, l]^2 + 
            779*Subscript[\[CapitalSigma], l]^2))))/(252*
      M^4) + \[Delta]*((14713254113*Sqrt[5]*
         Subscript[\[CapitalSigma], l])/(11266117632*M^2) - (256*
         Sqrt[5]*Pi*Subscript[S, l]*
         Subscript[\[CapitalSigma], l])/(21*
         M^4) + (Sqrt[
          5]*(1605952*Subscript[S, l]^2*
            Subscript[\[CapitalSigma], l] + 
           106463*Subscript[\[CapitalSigma], l]^3))/(48384*
         M^6)) + \[Nu]*(-((53090267*Sqrt[5]*Subscript[S, l])/(2095632*
           M^2)) - (1603*Sqrt[5]*Subscript[S, l]*
         Subscript[\[CapitalSigma], l]^2)/(27*M^6) + 
      Pi*(Plus[(256*Sqrt[5]*Subscript[\[CapitalSigma], l]^2)/(21*
            M^4)]) + \[Delta]*(-((66021037*Sqrt[5]*
              Subscript[\[CapitalSigma], l])/(5588352*M^2)) - (733*
            Sqrt[5]*Subscript[\[CapitalSigma], l]^3)/(84*M^6))); 
psim[3, 3, 
   7] = -((8*x^(7/2)*\[Nu]*Subscript[\[CapitalSigma], l])/(3*Sqrt[35]*
       M^2)); 
psim[3, 1, 
   7] = -((8*Sqrt[3/7]*x^(7/2)*\[Nu]*
       Subscript[\[CapitalSigma], l])/(5*M^2)); 
psim[4, 0, 
   5] = -((626077*Subscript[S, l])/(724416*M^2)) - (179791*\[Delta]*
      Subscript[\[CapitalSigma], l])/(271656*
      M^2) + \[Nu]*((989419*Subscript[S, l])/(232848*
         M^2) + (361055*\[Delta]*
         Subscript[\[CapitalSigma], l])/(155232*M^2)); 
psim[4, 0, 
   6] = \[Delta]*((25*Pi*Subscript[\[CapitalSigma], l])/(4032*
         M^2) + (1303525*Subscript[S, l]*
         Subscript[\[CapitalSigma], l])/(620928*M^4)) + ((1380815*
         Subscript[S, l]^2)/
       931392 + (352565*Subscript[\[CapitalSigma], l]^2)/516096)/
    M^4 + (\[Nu]^2*(26435*Subscript[\[CapitalSigma], l]^2))/(11088*
      M^4) + \[Nu]*(-((26435*\[Delta]*Subscript[S, l]*
           Subscript[\[CapitalSigma], l])/(11088*
           M^4)) - (5*(4737152*Subscript[S, l]^2 + 
           6517253*Subscript[\[CapitalSigma], l]^2))/(9934848*M^4)); 
psim[4, 0, 
   7] = (348470641109*Subscript[S, l])/(329533940736*
      M^2) + \[Nu]^2*((4773259*Subscript[S, l])/(5189184*
         M^2) + (5099915*\[Delta]*
         Subscript[\[CapitalSigma], l])/(6918912*M^2)) + (11776*
       Subscript[S, l]^3 + 
      2887*Subscript[S, l]*Subscript[\[CapitalSigma], l]^2)/(9072*
      M^6) + (Pi*(-768*Subscript[S, l]^2 - 
        193*Subscript[\[CapitalSigma], l]^2))/(756*
      M^4) + \[Delta]*((25969272883*
         Subscript[\[CapitalSigma], l])/(39943507968*M^2) - (64*Pi*
         Subscript[S, l]*Subscript[\[CapitalSigma], l])/(63*
         M^4) + ((2971*Subscript[S, l]^2*
            Subscript[\[CapitalSigma], l])/
          2268 - (55*Subscript[\[CapitalSigma], l]^3)/6912)/
       M^6) + \[Nu]*(-((712823899*Subscript[S, l])/(163459296*
           M^2)) - (109*Subscript[S, l]*
         Subscript[\[CapitalSigma], l]^2)/(81*
         M^6) + (Pi*(64*Subscript[\[CapitalSigma], l]^2))/(63*
         M^4) + \[Delta]*(-((160373197*
              Subscript[\[CapitalSigma], l])/(32288256*M^2)) - 
         Subscript[\[CapitalSigma], l]^3/(84*M^6))); 
psim[6, 0, 
   5] = -((373355*Subscript[S, l])/(931392*Sqrt[13]*
        M^2)) - (407135*\[Delta]*
      Subscript[\[CapitalSigma], l])/(1241856*Sqrt[13]*
      M^2) + \[Nu]*((19135*Subscript[S, l])/(11088*Sqrt[13]*
         M^2) + (16655*\[Delta]*Subscript[\[CapitalSigma], l])/(14784*
         Sqrt[13]*M^2)); 
psim[6, 0, 
   6] = (8005*\[Delta]*Subscript[S, l]*
      Subscript[\[CapitalSigma], l])/(44352*Sqrt[13]*
      M^4) + (5*(156544*Subscript[S, l]^2 + 
        76263*Subscript[\[CapitalSigma], l]^2))/(5677056*Sqrt[13]*
      M^4) + (\[Nu]^2*(215*Subscript[\[CapitalSigma], l]^2))/(528*
      Sqrt[13]*
      M^4) + \[Nu]*(-((215*\[Delta]*Subscript[S, l]*
           Subscript[\[CapitalSigma], l])/(528*Sqrt[13]*
           M^4)) - (5*(115584*Subscript[S, l]^2 + 
           99175*Subscript[\[CapitalSigma], l]^2))/(1419264*Sqrt[13]*
         M^4)); 
psim[6, 0, 
   7] = (1986903733*Subscript[S, l])/(1207084032*Sqrt[13]*
      M^2) + (106983697*\[Delta]*
      Subscript[\[CapitalSigma], l])/(73156608*Sqrt[13]*
      M^2) + \[Nu]*(-((10654115*Subscript[S, l])/(1197504*Sqrt[13]*
           M^2)) - (7026595*\[Delta]*
         Subscript[\[CapitalSigma], l])/(1064448*Sqrt[13]*
         M^2)) + \[Nu]^2*((198335*Subscript[S, l])/(19008*Sqrt[13]*
         M^2) + (10165*\[Delta]*Subscript[\[CapitalSigma], l])/(1584*
         Sqrt[13]*M^2)); 
psim[8, 0, 
   7] = (7786903*Subscript[S, l])/(40030848*Sqrt[17]*
      M^2) + (9147661*\[Delta]*
      Subscript[\[CapitalSigma], l])/(53374464*Sqrt[17]*
      M^2) + \[Nu]*(-((2586845*Subscript[S, l])/(2223936*Sqrt[17]*
           M^2)) - (2640475*\[Delta]*
         Subscript[\[CapitalSigma], l])/(2965248*Sqrt[17]*
         M^2)) + \[Nu]^2*((349685*Subscript[S, l])/(185328*Sqrt[17]*
         M^2) + (99085*\[Delta]*Subscript[\[CapitalSigma], l])/(82368*
         Sqrt[17]*M^2)); """
temp=term
for i in range(len(s)):
    temp=temp.replace(s[i],s_PsiM[i])
PsiM=temp
temp=term
for i in range(len(s)):
    temp=temp.replace(s[i],s_h[i])
h=temp
print(PsiM)
print(h)

# %%
s=['Subscript(\[Delta]\[Kappa],p)','Subscript(\[Delta]\[Kappa],M)','\[Nu]','Subscript(\[Kappa],p)','Subscript(\[CapitalSigma],n)','Subscript(\[CapitalSigma],\[ScriptL])','\[Delta]',
   'Subscript(S,\[ScriptL])','Subscript(S,n)','Subscript(\[Kappa],M)','  -  ',' ','\n','+','-']
s_h=['delta*kappa_p','delta*kappa_m','nu','kappa_p','Sigma_n','Sigma_ell','delta','S_ell','S_n','kappa_m','','','',' + ',' - ']
term = """(-4*\[Nu]**2*(2 + Subscript(\[Kappa],p))*Subscript(\[CapitalSigma],n)*
     -     Subscript(\[CapitalSigma],\[ScriptL]))/M**2 + 
     -  (6*\[Delta]*(Subscript(S,\[ScriptL])*Subscript(\[CapitalSigma],n) + 
     -       Subscript(S,n)*Subscript(\[CapitalSigma],\[ScriptL])))/M**2 + 
     -  (Subscript(S,n)*(Subscript(S,\[ScriptL])*
     -         (22 - 9*Subscript(\[Delta]\[Kappa],M) + 3*Subscript(\[Kappa],p)) + 
     -        6*(Subscript(\[Delta]\[Kappa],p) - Subscript(\[Kappa],M))*Subscript(\[CapitalSigma],\[ScriptL]))\
     -      + 6*Subscript(\[CapitalSigma],n)*
     -      (Subscript(S,\[ScriptL])*(Subscript(\[Delta]\[Kappa],p) - Subscript(\[Kappa],M)) + 
     -        (1 - Subscript(\[Delta]\[Kappa],M) + Subscript(\[Kappa],p))*Subscript(\[CapitalSigma],\[ScriptL]))
     -     )/(2.*M**2) + \[Nu]*((4*\[Delta]*
     -        (Subscript(S,\[ScriptL])*Subscript(\[CapitalSigma],n) + 
     -          Subscript(S,n)*Subscript(\[CapitalSigma],\[ScriptL])))/M**2 + 
     -     (2*Subscript(S,n)*
     -         (4*Subscript(S,\[ScriptL])*(2 + Subscript(\[Kappa],p)) + 
     -           (2*Subscript(\[Delta]\[Kappa],p) + 7*Subscript(\[Kappa],M))*
     -            Subscript(\[CapitalSigma],\[ScriptL])) + 
     -        Subscript(\[CapitalSigma],n)*
     -         (2*Subscript(S,\[ScriptL])*
     -            (2*Subscript(\[Delta]\[Kappa],p) + 7*Subscript(\[Kappa],M)) + 
     -           (-26 + 5*Subscript(\[Delta]\[Kappa],M) - 17*Subscript(\[Kappa],p))*
     -            Subscript(\[CapitalSigma],\[ScriptL])))/(2.*M**2))"""
for i in range(len(s)):
    term=term.replace(s[i],s_h[i])
print(term)
